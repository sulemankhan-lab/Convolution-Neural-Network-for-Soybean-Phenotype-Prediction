# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import layers
from keras import regularizers
from keras.models import Model
from keras.models import Sequential
from keras.layers import *
from keras.regularizers import l1,l2, L1L2
import keras
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping, Callback, ModelCheckpoint, ReduceLROnPlateau
from scipy.stats import pearsonr

# %%
##one of K encoding


nb_classes = 4

def indices_to_one_hot(data,nb_classes):

	targets = np.array(data).reshape(-1)

	return np.eye(nb_classes)[targets]

# %%
def readData(input):
    # Read the data
    data = pd.read_csv(input, sep='\t', header=0, na_values='nan')

    # Convert SNP, pheno, and folds columns to numeric, coercing errors to NaN
    SNP = data.iloc[:, 4:].apply(pd.to_numeric, errors='coerce').values
    pheno = pd.to_numeric(data.iloc[:, 1], errors='coerce').values
    folds = pd.to_numeric(data.iloc[:, 0], errors='coerce').values

    # Initialize the array to store one-hot encoded SNP data
    arr = np.empty(shape=(SNP.shape[0], SNP.shape[1], nb_classes))

    # Iterate over the rows to convert SNP values to one-hot encoding
    for i in range(0, SNP.shape[0]):
        arr[i] = indices_to_one_hot(pd.to_numeric(SNP[i], downcast='signed'), nb_classes)

    return arr, pheno, folds

# %%
def resnet(input):

	inputs = Input(shape=(input.shape[1],nb_classes))


	x = Conv1D(10,4,padding='same',activation = 'linear',kernel_initializer = 'TruncatedNormal', kernel_regularizer=regularizers.l2(0.1),bias_regularizer = regularizers.l2(0.01))(inputs)

	x = Conv1D(10,20,padding='same',activation = 'linear', kernel_initializer = 'TruncatedNormal',kernel_regularizer=regularizers.l2(0.1),bias_regularizer = regularizers.l2(0.01))(x)

	x = Dropout(0.75)(x)

	shortcut = Conv1D(10,4,padding='same',activation = 'linear',kernel_initializer = 'TruncatedNormal', kernel_regularizer=regularizers.l2(0.1),bias_regularizer = regularizers.l2(0.01))(inputs)
	x = layers.add([shortcut,x])

	x = Conv1D(10,4,padding='same',activation = 'linear',kernel_initializer = 'TruncatedNormal', kernel_regularizer=regularizers.l2(0.1),bias_regularizer = regularizers.l2(0.01))(x)

	x = Dropout(0.75)(x)
	x = Flatten()(x)

	x = Dropout(0.75)(x)

	outputs = Dense(1,activation = isru,bias_regularizer = regularizers.l2(0.01),kernel_initializer = 'TruncatedNormal',name = 'out')(x)

	model = Model(inputs = inputs,outputs = outputs)
	model.compile(loss='mean_squared_error',optimizer=keras.optimizers.Adam(learning_rate=0.001),metrics=['mae'])

	return model

# %%
a= 0.02

def isru(x):
	return  x/(tf.sqrt(1+a*tf.square(x)))

# %%
def model_train(test, val, train, testPheno, valPheno, trainPheno, model_save, weights_save):

	batch_size = 250
	early_stop = 5
	epoch = 10
	early_stopping = EarlyStopping(monitor='val_mae', mode='min', patience=early_stop, verbose=1, restore_best_weights=True)

	model = resnet(train)
	history = model.fit(train, trainPheno, batch_size=batch_size, epochs=epoch, validation_data=(val, valPheno), callbacks=[early_stopping], shuffle= True)

	#model.save(model_save)
	#model.save_weights(weights_save)

	pred = model.predict(test)
	pred.shape = (pred.shape[0],)
	corr = pearsonr(pred,testPheno)[0]

	return history,corr

# %%
def main(IMP_input,QA_input):

	IMP_corr=[]
	QA_corr = []

	imp_SNP,imp_pheno, folds = readData(IMP_input)
	QA_SNP,QA_pheno, folds = readData(QA_input)

	PHENOTYPE = imp_pheno

	for i in range(1,11):

		testIdx = np.where(folds == i)
		if i == 10:
			valIdx = np.where(folds == 1)
			trainIdx = np.intersect1d(np.where(folds != i),np.where(folds != 1))
		else:
			valIdx = np.where(folds == i+1)
			trainIdx = np.intersect1d(np.where(folds != i),np.where(folds != i+1))

		trainSNP, trainSNP_QA , trainPheno = imp_SNP[trainIdx], QA_SNP[trainIdx], PHENOTYPE[trainIdx]
		valSNP, valSNP_QA, valPheno = imp_SNP[valIdx],QA_SNP[valIdx], PHENOTYPE[valIdx]
		testSNP, testSNP_QA, testPheno = imp_SNP[testIdx],QA_SNP[testIdx], PHENOTYPE[testIdx]

		history, corr = model_train(testSNP,valSNP,trainSNP,testPheno,valPheno,trainPheno,'model_IMP/model_'+str(i)+'.txt','model_IMP/model_weights'+str(i)+'.h5')
		IMP_corr.append(float('%0.4f' % corr))

		history, corr = model_train(testSNP_QA,valSNP_QA,trainSNP_QA,testPheno,valPheno,trainPheno,'model_QA/model_'+str(i)+'.txt','model_QA/model_weights'+str(i)+'.h5')
		QA_corr.append(float('%0.4f' % corr))

	print ("Average PCC (imputed) from 10-fold cross validation: " + str(np.mean(IMP_corr)))
	print ("Average PCC (non-imputed) from 10-fold cross validation: " + str(np.mean(QA_corr)))

# %%
if __name__ == '__main__':

	#os.chdir("MOISTURE")

	IMP_input =  "IMP_moisture.txt"
	QA_input = "QA_moisture.txt"

	main(IMP_input,QA_input)
# Out:
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 2.2137 - mae: 1.0244 - val_loss: 1.3230 - val_mae: 0.7231
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.5435 - mae: 0.8189 - val_loss: 1.2540 - val_mae: 0.7218
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4267 - mae: 0.7929 - val_loss: 1.1921 - val_mae: 0.7189
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.3629 - mae: 0.7848 - val_loss: 1.1429 - val_mae: 0.7164
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.2922 - mae: 0.7802 - val_loss: 1.0961 - val_mae: 0.7118
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 1.2312 - mae: 0.7647 - val_loss: 1.0594 - val_mae: 0.7135
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2002 - mae: 0.7603 - val_loss: 1.0242 - val_mae: 0.7064
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1558 - mae: 0.7569 - val_loss: 0.9935 - val_mae: 0.7051
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1317 - mae: 0.7602 - val_loss: 0.9624 - val_mae: 0.6968
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0902 - mae: 0.7492 - val_loss: 0.9372 - val_mae: 0.6935
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 2.4129 - mae: 1.0922 - val_loss: 1.3238 - val_mae: 0.7190
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.6792 - mae: 0.8661 - val_loss: 1.2538 - val_mae: 0.7049
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.4617 - mae: 0.7974 - val_loss: 1.2026 - val_mae: 0.6994
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.3878 - mae: 0.7832 - val_loss: 1.1531 - val_mae: 0.6937
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.3191 - mae: 0.7607 - val_loss: 1.1030 - val_mae: 0.6833
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.2981 - mae: 0.7658 - val_loss: 1.0594 - val_mae: 0.6741
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1846 - mae: 0.7354 - val_loss: 1.0242 - val_mae: 0.6712
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.1553 - mae: 0.7266 - val_loss: 0.9866 - val_mae: 0.6630
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.0793 - mae: 0.7153 - val_loss: 0.9593 - val_mae: 0.6601
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1232 - mae: 0.7310 - val_loss: 0.9267 - val_mae: 0.6517
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 2.2220 - mae: 1.0277 - val_loss: 1.4959 - val_mae: 0.8032
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.6098 - mae: 0.8329 - val_loss: 1.4223 - val_mae: 0.7975
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.4812 - mae: 0.8133 - val_loss: 1.3615 - val_mae: 0.7908
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.3757 - mae: 0.7825 - val_loss: 1.3108 - val_mae: 0.7893
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.2940 - mae: 0.7685 - val_loss: 1.2619 - val_mae: 0.7858
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2783 - mae: 0.7790 - val_loss: 1.2171 - val_mae: 0.7791
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.2141 - mae: 0.7690 - val_loss: 1.1774 - val_mae: 0.7737
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1852 - mae: 0.7638 - val_loss: 1.1389 - val_mae: 0.7684
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0958 - mae: 0.7395 - val_loss: 1.1053 - val_mae: 0.7616
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1042 - mae: 0.7527 - val_loss: 1.0750 - val_mae: 0.7544
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 2.5289 - mae: 1.1160 - val_loss: 1.5003 - val_mae: 0.7979
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.6293 - mae: 0.8408 - val_loss: 1.4217 - val_mae: 0.7814
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4356 - mae: 0.7866 - val_loss: 1.3560 - val_mae: 0.7707
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.3894 - mae: 0.7700 - val_loss: 1.2890 - val_mae: 0.7620
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.3132 - mae: 0.7644 - val_loss: 1.2276 - val_mae: 0.7500
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.2162 - mae: 0.7380 - val_loss: 1.1679 - val_mae: 0.7359
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2017 - mae: 0.7449 - val_loss: 1.1198 - val_mae: 0.7232
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1465 - mae: 0.7221 - val_loss: 1.0794 - val_mae: 0.7187
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.0895 - mae: 0.7126 - val_loss: 1.0389 - val_mae: 0.7124
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 1.0782 - mae: 0.7203 - val_loss: 1.0159 - val_mae: 0.7069
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 2.3491 - mae: 1.0375 - val_loss: 1.5439 - val_mae: 0.7782
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.5283 - mae: 0.8016 - val_loss: 1.4748 - val_mae: 0.7747
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.4266 - mae: 0.7928 - val_loss: 1.4198 - val_mae: 0.7706
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.3197 - mae: 0.7686 - val_loss: 1.3733 - val_mae: 0.7713
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.3231 - mae: 0.7747 - val_loss: 1.3251 - val_mae: 0.7703
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.2528 - mae: 0.7678 - val_loss: 1.2834 - val_mae: 0.7675
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1684 - mae: 0.7594 - val_loss: 1.2504 - val_mae: 0.7635
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.2147 - mae: 0.7779 - val_loss: 1.2205 - val_mae: 0.7610
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1161 - mae: 0.7549 - val_loss: 1.1882 - val_mae: 0.7587
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 1.0632 - mae: 0.7430 - val_loss: 1.1581 - val_mae: 0.7531
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - loss: 2.1915 - mae: 1.0071 - val_loss: 1.5074 - val_mae: 0.7664
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.6045 - mae: 0.8342 - val_loss: 1.4376 - val_mae: 0.7570
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.4266 - mae: 0.7826 - val_loss: 1.3779 - val_mae: 0.7501
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2827 - mae: 0.7459 - val_loss: 1.3169 - val_mae: 0.7447
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2517 - mae: 0.7488 - val_loss: 1.2596 - val_mae: 0.7329
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - loss: 1.1612 - mae: 0.7221 - val_loss: 1.2051 - val_mae: 0.7271
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1071 - mae: 0.7204 - val_loss: 1.1575 - val_mae: 0.7243
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.0661 - mae: 0.7142 - val_loss: 1.1205 - val_mae: 0.7146
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.0209 - mae: 0.7054 - val_loss: 1.0851 - val_mae: 0.7115
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.0246 - mae: 0.7087 - val_loss: 1.0579 - val_mae: 0.7108
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 2.9005 - mae: 1.2134 - val_loss: 1.4396 - val_mae: 0.7832
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.6354 - mae: 0.8487 - val_loss: 1.3850 - val_mae: 0.7761
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.4954 - mae: 0.8048 - val_loss: 1.3277 - val_mae: 0.7674
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 1.4247 - mae: 0.7950 - val_loss: 1.2891 - val_mae: 0.7710
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.3958 - mae: 0.8000 - val_loss: 1.2490 - val_mae: 0.7642
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.3530 - mae: 0.7822 - val_loss: 1.2151 - val_mae: 0.7627
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.2828 - mae: 0.7717 - val_loss: 1.1792 - val_mae: 0.7636
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.2481 - mae: 0.7716 - val_loss: 1.1429 - val_mae: 0.7559
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1703 - mae: 0.7542 - val_loss: 1.1145 - val_mae: 0.7536
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.1773 - mae: 0.7639 - val_loss: 1.0852 - val_mae: 0.7488
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - loss: 2.3500 - mae: 1.0585 - val_loss: 1.3944 - val_mae: 0.7685
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 1.5325 - mae: 0.8104 - val_loss: 1.3108 - val_mae: 0.7534
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.4174 - mae: 0.7863 - val_loss: 1.2430 - val_mae: 0.7409
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.3256 - mae: 0.7622 - val_loss: 1.1728 - val_mae: 0.7270
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 993ms/step - loss: 1.2303 - mae: 0.7424 - val_loss: 1.1134 - val_mae: 0.7144
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 1.2092 - mae: 0.7388 - val_loss: 1.0548 - val_mae: 0.7010
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.1573 - mae: 0.7388 - val_loss: 1.0102 - val_mae: 0.6906
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0890 - mae: 0.7195 - val_loss: 0.9686 - val_mae: 0.6863
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.1126 - mae: 0.7346 - val_loss: 0.9327 - val_mae: 0.6699
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.0343 - mae: 0.7181 - val_loss: 0.9070 - val_mae: 0.6726
# Restoring model weights from the end of the best epoch: 9.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 2.2560 - mae: 1.0308 - val_loss: 1.4893 - val_mae: 0.7526
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.5284 - mae: 0.8039 - val_loss: 1.4295 - val_mae: 0.7471
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.4077 - mae: 0.7869 - val_loss: 1.3740 - val_mae: 0.7471
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.3843 - mae: 0.7866 - val_loss: 1.3267 - val_mae: 0.7387
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 1.3313 - mae: 0.7780 - val_loss: 1.2836 - val_mae: 0.7395
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2646 - mae: 0.7636 - val_loss: 1.2397 - val_mae: 0.7334
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.2193 - mae: 0.7590 - val_loss: 1.2017 - val_mae: 0.7308
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.1721 - mae: 0.7537 - val_loss: 1.1621 - val_mae: 0.7246
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1529 - mae: 0.7522 - val_loss: 1.1243 - val_mae: 0.7188
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1476 - mae: 0.7569 - val_loss: 1.0896 - val_mae: 0.7136
# Restoring model weights from the end of the best epoch: 10.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 2.5202 - mae: 1.0973 - val_loss: 1.4825 - val_mae: 0.7356
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.6170 - mae: 0.8344 - val_loss: 1.3971 - val_mae: 0.7263
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.4845 - mae: 0.8036 - val_loss: 1.3256 - val_mae: 0.7195
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.3741 - mae: 0.7739 - val_loss: 1.2558 - val_mae: 0.7059
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.3097 - mae: 0.7571 - val_loss: 1.1958 - val_mae: 0.6975
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 889ms/step - loss: 1.2037 - mae: 0.7406 - val_loss: 1.1388 - val_mae: 0.6878
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 949ms/step - loss: 1.1715 - mae: 0.7302 - val_loss: 1.0951 - val_mae: 0.6840
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 848ms/step - loss: 1.1469 - mae: 0.7372 - val_loss: 1.0635 - val_mae: 0.6803
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 852ms/step - loss: 1.1126 - mae: 0.7309 - val_loss: 1.0216 - val_mae: 0.6722
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 1.0340 - mae: 0.7091 - val_loss: 0.9968 - val_mae: 0.6691
# Restoring model weights from the end of the best epoch: 10.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 2.3968 - mae: 1.0813 - val_loss: 1.5455 - val_mae: 0.8073
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.5964 - mae: 0.8320 - val_loss: 1.4941 - val_mae: 0.7999
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4145 - mae: 0.7765 - val_loss: 1.4424 - val_mae: 0.7975
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.3413 - mae: 0.7661 - val_loss: 1.3998 - val_mae: 0.7944
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.3452 - mae: 0.7840 - val_loss: 1.3583 - val_mae: 0.7912
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2429 - mae: 0.7643 - val_loss: 1.3212 - val_mae: 0.7910
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2264 - mae: 0.7604 - val_loss: 1.2921 - val_mae: 0.7872
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.2041 - mae: 0.7593 - val_loss: 1.2550 - val_mae: 0.7846
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.1420 - mae: 0.7432 - val_loss: 1.2245 - val_mae: 0.7802
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1393 - mae: 0.7547 - val_loss: 1.1953 - val_mae: 0.7751
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 2.1196 - mae: 0.9891 - val_loss: 1.5176 - val_mae: 0.7914
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.5890 - mae: 0.8251 - val_loss: 1.4398 - val_mae: 0.7774
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.4084 - mae: 0.7797 - val_loss: 1.3795 - val_mae: 0.7715
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 1.3331 - mae: 0.7631 - val_loss: 1.3149 - val_mae: 0.7636
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.2305 - mae: 0.7443 - val_loss: 1.2559 - val_mae: 0.7523
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.2266 - mae: 0.7462 - val_loss: 1.1925 - val_mae: 0.7376
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.1735 - mae: 0.7374 - val_loss: 1.1407 - val_mae: 0.7289
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.1536 - mae: 0.7371 - val_loss: 1.0987 - val_mae: 0.7187
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.0801 - mae: 0.7221 - val_loss: 1.0636 - val_mae: 0.7170
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.0461 - mae: 0.7114 - val_loss: 1.0272 - val_mae: 0.7075
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 2.3006 - mae: 1.0473 - val_loss: 1.4241 - val_mae: 0.7617
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.5713 - mae: 0.8206 - val_loss: 1.3511 - val_mae: 0.7591
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4335 - mae: 0.7910 - val_loss: 1.2908 - val_mae: 0.7578
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 1.3060 - mae: 0.7674 - val_loss: 1.2328 - val_mae: 0.7506
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.2925 - mae: 0.7731 - val_loss: 1.1909 - val_mae: 0.7494
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2267 - mae: 0.7568 - val_loss: 1.1502 - val_mae: 0.7498
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1928 - mae: 0.7622 - val_loss: 1.1085 - val_mae: 0.7414
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1761 - mae: 0.7603 - val_loss: 1.0753 - val_mae: 0.7409
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1051 - mae: 0.7469 - val_loss: 1.0467 - val_mae: 0.7375
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1083 - mae: 0.7533 - val_loss: 1.0137 - val_mae: 0.7281
# Restoring model weights from the end of the best epoch: 10.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 2.3239 - mae: 1.0626 - val_loss: 1.4002 - val_mae: 0.7427
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.5666 - mae: 0.8230 - val_loss: 1.3296 - val_mae: 0.7350
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4654 - mae: 0.7842 - val_loss: 1.2739 - val_mae: 0.7278
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.3648 - mae: 0.7616 - val_loss: 1.2214 - val_mae: 0.7247
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 1.2993 - mae: 0.7544 - val_loss: 1.1650 - val_mae: 0.7130
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.2344 - mae: 0.7454 - val_loss: 1.1088 - val_mae: 0.6983
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.1715 - mae: 0.7214 - val_loss: 1.0657 - val_mae: 0.6922
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.1072 - mae: 0.7133 - val_loss: 1.0330 - val_mae: 0.6877
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0966 - mae: 0.7142 - val_loss: 1.0008 - val_mae: 0.6867
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.0697 - mae: 0.7138 - val_loss: 0.9695 - val_mae: 0.6816
# Restoring model weights from the end of the best epoch: 10.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 2.7461 - mae: 1.1594 - val_loss: 1.4645 - val_mae: 0.7678
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.6971 - mae: 0.8555 - val_loss: 1.4066 - val_mae: 0.7628
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.4922 - mae: 0.7974 - val_loss: 1.3546 - val_mae: 0.7632
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.4134 - mae: 0.7877 - val_loss: 1.3093 - val_mae: 0.7587
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - loss: 1.3443 - mae: 0.7761 - val_loss: 1.2680 - val_mae: 0.7563
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - loss: 1.2830 - mae: 0.7661 - val_loss: 1.2300 - val_mae: 0.7542
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2784 - mae: 0.7760 - val_loss: 1.1946 - val_mae: 0.7501
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.2150 - mae: 0.7635 - val_loss: 1.1621 - val_mae: 0.7503
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.1957 - mae: 0.7602 - val_loss: 1.1300 - val_mae: 0.7421
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - loss: 1.1847 - mae: 0.7579 - val_loss: 1.1004 - val_mae: 0.7390
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - loss: 2.1190 - mae: 0.9896 - val_loss: 1.3959 - val_mae: 0.7596
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.5335 - mae: 0.8173 - val_loss: 1.3188 - val_mae: 0.7471
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.4325 - mae: 0.8010 - val_loss: 1.2411 - val_mae: 0.7349
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.3175 - mae: 0.7623 - val_loss: 1.1739 - val_mae: 0.7279
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.2265 - mae: 0.7422 - val_loss: 1.1079 - val_mae: 0.7142
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1754 - mae: 0.7343 - val_loss: 1.0621 - val_mae: 0.7114
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - loss: 1.0754 - mae: 0.7145 - val_loss: 1.0092 - val_mae: 0.6948
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.0484 - mae: 0.7105 - val_loss: 0.9755 - val_mae: 0.6915
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.0311 - mae: 0.7106 - val_loss: 0.9514 - val_mae: 0.6899
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 0.9877 - mae: 0.7097 - val_loss: 0.9201 - val_mae: 0.6841
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 2.2702 - mae: 1.0243 - val_loss: 1.4682 - val_mae: 0.7733
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.6074 - mae: 0.8295 - val_loss: 1.3996 - val_mae: 0.7654
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.4594 - mae: 0.7922 - val_loss: 1.3446 - val_mae: 0.7642
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.3504 - mae: 0.7794 - val_loss: 1.2915 - val_mae: 0.7612
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.3605 - mae: 0.7873 - val_loss: 1.2441 - val_mae: 0.7590
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - loss: 1.2690 - mae: 0.7799 - val_loss: 1.2074 - val_mae: 0.7566
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.2025 - mae: 0.7612 - val_loss: 1.1689 - val_mae: 0.7535
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.1574 - mae: 0.7474 - val_loss: 1.1332 - val_mae: 0.7490
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - loss: 1.1253 - mae: 0.7514 - val_loss: 1.1011 - val_mae: 0.7441
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.0680 - mae: 0.7358 - val_loss: 1.0716 - val_mae: 0.7386
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - loss: 2.3766 - mae: 1.0668 - val_loss: 1.4370 - val_mae: 0.7653
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.5377 - mae: 0.8101 - val_loss: 1.3641 - val_mae: 0.7584
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 1.3995 - mae: 0.7785 - val_loss: 1.2944 - val_mae: 0.7484
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 1.3394 - mae: 0.7736 - val_loss: 1.2291 - val_mae: 0.7378
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 1.2219 - mae: 0.7374 - val_loss: 1.1614 - val_mae: 0.7257
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.1989 - mae: 0.7452 - val_loss: 1.1101 - val_mae: 0.7151
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.1801 - mae: 0.7521 - val_loss: 1.0704 - val_mae: 0.7110
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.0771 - mae: 0.7235 - val_loss: 1.0254 - val_mae: 0.7001
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 1.0490 - mae: 0.7134 - val_loss: 0.9956 - val_mae: 0.6956
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 0.9679 - mae: 0.6893 - val_loss: 0.9678 - val_mae: 0.6905
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - loss: 2.6589 - mae: 1.1377 - val_loss: 1.4369 - val_mae: 0.7591
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 1.6201 - mae: 0.8192 - val_loss: 1.3762 - val_mae: 0.7537
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - loss: 1.4793 - mae: 0.7934 - val_loss: 1.3292 - val_mae: 0.7510
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.4147 - mae: 0.7811 - val_loss: 1.2889 - val_mae: 0.7534
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - loss: 1.3631 - mae: 0.7815 - val_loss: 1.2504 - val_mae: 0.7537
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.3176 - mae: 0.7708 - val_loss: 1.2072 - val_mae: 0.7435
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2780 - mae: 0.7651 - val_loss: 1.1722 - val_mae: 0.7441
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2495 - mae: 0.7688 - val_loss: 1.1392 - val_mae: 0.7404
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.2019 - mae: 0.7488 - val_loss: 1.1107 - val_mae: 0.7396
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.1228 - mae: 0.7354 - val_loss: 1.0779 - val_mae: 0.7331
# Restoring model weights from the end of the best epoch: 10.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 2.4234 - mae: 1.0704 - val_loss: 1.3872 - val_mae: 0.7485
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.6366 - mae: 0.8489 - val_loss: 1.3150 - val_mae: 0.7402
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.4469 - mae: 0.7918 - val_loss: 1.2498 - val_mae: 0.7325
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - loss: 1.3576 - mae: 0.7713 - val_loss: 1.1846 - val_mae: 0.7215
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - loss: 1.3014 - mae: 0.7587 - val_loss: 1.1221 - val_mae: 0.7093
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2404 - mae: 0.7451 - val_loss: 1.0709 - val_mae: 0.7035
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 1.2033 - mae: 0.7438 - val_loss: 1.0272 - val_mae: 0.6961
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0989 - mae: 0.7250 - val_loss: 0.9895 - val_mae: 0.6929
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0604 - mae: 0.7056 - val_loss: 0.9609 - val_mae: 0.6885
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - loss: 1.0069 - mae: 0.6995 - val_loss: 0.9464 - val_mae: 0.6957
# Restoring model weights from the end of the best epoch: 9.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# Average PCC (imputed) from 10-fold cross validation: 0.37273
# Average PCC (non-imputed) from 10-fold cross validation: 0.4452900000000001
